# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import  make_blobs

# %%
X , y = make_blobs(n_samples=100, n_features=2 , centers=2, random_state=0)
y =  y.reshape(y.shape[0], 1)

print("Diemension of X: ", X.shape)
print("Diemension of y: ", y.shape)
# Out:
# Diemension of X:  (100, 2)
# Diemension of y:  (100, 1)

# %%
plt.figure()
plt.scatter(X[:,0], X[:,1], c=y, s=50, cmap='summer')
plt.show()

# %%
def initialisation(X):
    w = np.random.randn(X.shape[1], 1)
    b = np.random.randn(1)
    return w, b

# %%
w , b  = initialisation(X)

# %%
b
# Out:
# array([0.86227599])

# %%
def model(X , w , b):
     Z = np.dot(X, w) + b
     A = 1/(1 + np.exp(-Z))
     return A

# %%
A =  model(X, w, b)
print("A shape: ", A.shape)
# Out:
# A shape:  (100, 1)

# %%
def log_loss(A , y):
    L = -(1/len(y))*np.sum(y*np.log(A) +  (1-y)*np.log(1-A))
    return L

# %%
print("Log loss: ", log_loss(A, y))
# Out:
# Log loss:  0.6367285098404751

# %%
def gradient(X, y, A):
    dw = 1/len(y)* np.dot(np.transpose(X),A - y)
    db = (1/len(y))*np.sum(A - y)
    return dw , db

# %%
dw , db = gradient(X, y, A)

# %%
dw.shape
# Out:
# (2, 1)

# %%
print("gradient de w = " , dw)
print("Gradient de b = " , db)
# Out:
# gradient de w =  [[0.35125294]
#  [1.20851353]]
# Gradient de b =  0.2601228814738038

# %%
def update( dw, db , w , b , learning_rate ):
    w = w - learning_rate*dw 
    b = b - learning_rate*db
    return w , b
